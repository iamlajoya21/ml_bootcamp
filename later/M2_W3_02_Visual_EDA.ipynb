# %% [markdown]
# # Month 2 - Week 3 - Class 2: Visual EDA (Deep Dive & Real Data)
#
# ## 1. Visualizing Distributions (Penguins)
#
# We use the Palmer Penguins dataset. It's the new Iris.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

penguins = sns.load_dataset('penguins').dropna()

# Violin Plot
sns.violinplot(data=penguins, x="species", y="body_mass_g")
plt.title("Body Mass Distribution by Species")
plt.show()

# %% [markdown]
# ## 2. Heatmaps
#
# Correlation of numeric features.

# %%
corr = penguins.corr()
sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.title("Penguin Features Correlation")
plt.show()

# %% [markdown]
# ## 3. Pair Plots
#
# The ultimate EDA tool.

# %%
sns.pairplot(penguins, hue="species")
plt.show()

# %% [markdown]
# ---
# ## Practice Drills
# 10 exercises to build muscle memory.
#
# 1. **Histogram**: Create a histogram of `body_mass_g`.

# %%
# Code here

# %% [markdown]
# 2. **Scatter**: Create a scatterplot of `bill_length_mm` vs `bill_depth_mm`.

# %%
# Code here

# %% [markdown]
# 3. **Boxplot**: Boxplot of `body_mass_g` grouped by `sex`.

# %%
# Code here

# %% [markdown]
# 4. **Countplot**: Count frequencies of `species`.

# %%
# Code here

# %% [markdown]
# 5. **Barplot**: Mean `body_mass_g` by `species` (Bar chart).

# %%
# Code here

# %% [markdown]
# 6. **Violin**: Create a violin plot for `bill_length_mm` by `island`.

# %%
# Code here

# %% [markdown]
# 7. **Hue**: Add `hue="sex"` to your scatterplot.

# %%
# Code here

# %% [markdown]
# 8. **FacetGrid**: Create a FacetGrid with columns for `species` and map a histogram.

# %%
# Code here

# %% [markdown]
# 9. **Swarm**: Try `sns.swarmplot` on `body_mass_g` (might be slow/cluttered).

# %%
# Code here

# %% [markdown]
# 10. **Regression**: Use `sns.lmplot` to fit a regression line on scatter.

# %%
# Code here

# %% [markdown]
# ---
# # HOMEWORK: Insight Hunter (Real Data - MPG)
#
# **Objective**: Analyze cars.
#
# 1. Load `sns.load_dataset('mpg')`.
# 2. **Scatter**: Weight vs MPG (hue=origin).
# 3. **Boxplot**: MPG by Origin.
# 4. **Heatmap**: Correlation.
