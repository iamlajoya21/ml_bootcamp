# %% [markdown]
# # Month 2 - Week 1 - Class 1: Data Loading (Deep Dive & Real Data)
#
# ## 1. Chunking Large Data
#
# Using a real CSV from GitHub.

# %%
import pandas as pd
import io
import requests

# Titanic URL (Raw)
url = "https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv"

# Read in chunks (simulating a large file)
chunk_size = 100
for chunk in pd.read_csv(url, chunksize=chunk_size):
    print(f"Chunk shape: {chunk.shape}")
    # Break after first chunk for demo
    break

# %% [markdown]
# ## 2. API Data
#
# Fetching Crypto data (CoinGecko Public API).

# %%
# Fetch Bitcoin price
api_url = "https://api.coingecko.com/api/v3/simple/price?ids=bitcoin&vs_currencies=usd"
response = requests.get(api_url)
if response.status_code == 200:
    print("Bitcoin Price:", response.json())
else:
    print("Failed to fetch")

# %% [markdown]
# ---
# ## Practice Drills
# 10 exercises to build muscle memory.
#
# 1. **CSV Write**: Create a DataFrame and save it to `test.csv`.

# %%
# Code here

# %% [markdown]
# 2. **CSV Read**: Read `test.csv` back into a DataFrame.

# %%
# Code here

# %% [markdown]
# 3. **JSON**: Save your DataFrame to `test.json`.

# %%
# Code here

# %% [markdown]
# 4. **Excel**: (Requires openpyxl) Save to `test.xlsx`.

# %%
# Code here

# %% [markdown]
# 5. **Read Cols**: Read only the first column of `test.csv` using `usecols`.

# %%
# Code here

# %% [markdown]
# 6. **Read N Rows**: Read only the first 2 rows of `test.csv`.

# %%
# Code here

# %% [markdown]
# 7. **Head**: Print the first 2 rows of the Titanic dataset (load from seaborn).

# %%
# Code here

# %% [markdown]
# 8. **Tail**: Print the last 2 rows.

# %%
# Code here

# %% [markdown]
# 9. **Sample**: Print a random sample of 5 rows.

# %%
# Code here

# %% [markdown]
# 10. **Dtypes**: Print the data types of the Titanic columns.

# %%
# Code here

# %% [markdown]
# ---
# # HOMEWORK: API Fetcher
#
# **Objective**: Create a dataset from the web.
#
# 1. **Find an API**: (e.g., OpenMeteo for weather history).
# 2. **Fetch**: Get 7 days of temperature data for NY.
# 3. **Parse**: Convert to DF with columns 'Time' and 'Temp'.
# 4. **Save**: Parquet.
