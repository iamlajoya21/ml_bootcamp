# %%
# Problem 1: The VIP List Write a program that asks for a person's age. 
# If they are 18 or older, print "Welcome to the club!" 
# Otherwise, print "Access denied: you are too young."  


age = int(input())

if age >= 18:
    print("Welcome to the club!")
else: 
    print("Access denied: you are too young.")
# Out:
# Access denied: you are too young.

# %%
# Problem 2: The Number Detective Ask the user for a number.
# If the number is greater than 0, print "This is a positive number."
# If the number is less than 0, print "This is a negative number."
# If the number is exactly 0, print "This is zero."



age = int(input("Give me a  number"))

if age > 0:
    print("Positive number")

elif age == 0:
    print("This is a zero")

else: 
    print("This is a negative number.")
# Out:
# Welcome to the club!

# %%
# Problem 3: Even or Odd? Ask the user for a whole number. 
# Use the modulo operator % to find out if the number is even or odd.

nmb = int(input("Give me a number"))

answer = nmb % 2
if answer == 0:
    print(nmb,'Number is even')
else:
    print(nmb,'Number is odd')
# Out:
# 8 Number is even

# %%
# Problem 3: Even or Odd? Ask the user for a whole number. 
# Use the modulo operator % to find out if the number is even or odd.

nmb = int(input("Give me a number"))


if nmb % 2  == 0:
    print(nmb,'Number is even')
else:
    print(nmb,'Number is odd')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 4
#       1 # Problem 3: Even or Odd? Ask the user for a whole number.
#       2 # Use the modulo operator % to find out if the number is even or odd.
# ----> 4 nmb = int(input("Give me a number"))
#       7 if nmb % 2  == 0:
#       8     print(nmb,'Number is even')
#
# ValueError: invalid literal for int() with base 10: ''

# %%
print(14//4)
print(14%4)
# Out:
# 3
# 2

# %% [markdown]
# You will ask the temperature from the user for the parking space, house and balcony: You shall return the location of the place by hooising the location with the medium temperature

# %%
space = int(input("Space: "))
hause = int(input ("Hause: "))
balcony = int(input("Balcony: "))
if (hause > space and hause < balcony) or (hause < space and hause >balcony): 
    print ("The medium temp is in hause")
elif (space > hause and space < balcony) or (space < hause and space > balcony):
    print("The medium temp is in space")
else:
    print ("The mediun temp is in balcony")
# Out:
# The medium temp is in space

# %%
temp = int(input("Enter temperature in Celsius in parking space "))
temp1 = int(input("Enter temperature in Celsius in house "))
temp2 = int(input("Enter temperature in Celsius in balcony "))
if temp > temp1 > temp2 or temp2 > temp1 > temp:
    print("Put it in house")
elif temp2 > temp > temp1 or temp1 > temp > temp2:
    print("Put it in parking space")
else:
    print("put it in balcony")

# %%
temp_b

# %%
# Problem 4: 
# The Math Bot Build a program that asks for two whole numbers. Then, ask the user: "Type 1 to Add or 2 to Subtract."
# If they type 1, print the sum of the two numbers.
# If they type 2, print the difference.
# If they type anything else, print "Error: Invalid Choice."

# %%
# Problem 4: 
# The Math Bot Build a program that asks for two whole numbers. Then, ask the user: "Type 1 to Add or 2 to Subtract."
# If they type 1, print the sum of the two numbers.
# If they type 2, print the difference.
# If they type anything else, print "Error: Invalid Choice."
nmb1 = int(input("Give me 1st number"))
nmb2 = int(input("Give me 2nd number"))
operator = int(input("Type 1  or Type 2"))
if operator == 1:
    print(nmb1 + nmb2)
elif operator == 2:
    print(nmb1 - nmb2)
else: 
    print("Error: Invalid Choice.")
# Out:
# 8

# %% [markdown]
# <h1> New Topics </h1>

# %%
x = 10.5
pi = 3.14
e = 2.71828

# %%
e
# Out:
# 2.71828

# %%
import math

x = 9
y = math.sqrt(x)

print(y)  # prints 3.0
# Out:
# 3.0

# %%
from math import sqrt

sqrt(122)
# Out:
# 11.045361017187261

# %%
y
# Out:
# 11.045361017187261

# %%
x = -10.5
z = 15


print(abs(x))
print(abs(z))
# Out:
# 10.5
# 15

# %%
print(sqrt(122))
print(round(sqrt(122), 3))
print(round(sqrt(122), None) )

print(round(11.5))
# Out:
# 11.045361017187261
# 11.045
# 11
# 12

# %%
print(math.ceil(10.1))

print(math.floor(10.1))
# Out:
# 11
# 10

# %%
abs(x)

# ceil(x): Returns the smallest integer that is greater than or equal to a number. For example, ceil(3.2) would return 4.

# floor(x)
math.sqrt(x)
math.exp(x)
# Out:
# 8103.083927575384

# %%
math.log(8)
# Out:
# 2.0794415416798357

# %%
x = 10.5
pi = 3.14

sum = x + pi
difference = x - pi
product = x * pi
quotient = x / pi


print(product)
# Out:
# 32.97

# %%
x = 10
y = 5

# Shorthand for x = x + y
print(x)
x += y  # x is now 15
print(x)
# # Shorthand for x = x - y
x -= y  # x is now 10

# Shorthand for x = x * y
x *= y  # x is now 50

# Shorthand for x = x / y
x /= y  # x is now 10.0

# Shorthand for x = x % y
x %= y  # x is now 0
# Out:
# 10
# 15

# %%
hello = "Hello, World!"
s = 'This is a string'


s = 'Hello, World!'
length = len(s)        # length is 12
print(length, len(s))  # prints 12 12
# Out:
# 13 13

# %%
s[:-5]
# Out:
# 'Hello, W'

# %%
s = "Hello, World!"

# Get the first character
first_char = s[0]  # first_char is 'H'
print(first_char)
# Get the last character
last_char = s[-1]  # last_char is '!'
print(last_char)
# Out:
# H
# !

# %%
s = 'Hello, World!'

# Get the first five characters
substring = s[0:5]  # substring is 'Hello'
print(substring)
# Get all characters except the first and last
substring = s[1:-2]  # substring is 'ello, World'
print(substring)
# Out:
# Hello
# ello, Worl

# %%
s = 'Hello, World!'

# Concatenate two strings (will print Hello, World! Nice meeting you!)
print(s + ' Nice meeting you!')
# Out:
# Hello, World! Nice meeting you!

# %%
d = 'How are you doing?'

e = s+' '+d
print(e)
# Out:
# Hello, World! How are you doing?

# %%
# Replace a character
s[0] = 'h'  # This will produce an error as strings are immutable
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[83], line 2
#       1 # Replace a character
# ----> 2 s[0] = 'h'  # This will produce an error as strings are immutable
#
# TypeError: 'str' object does not support item assignment

# %%
# Concatenate two strings
s = 'Hello, World!'
s += ' How are you?'  # s is now "Hello, World! How are you?"
print(s)
# Out:
# Hello, World! How are you?

# %%
# Make a string uppercase
s = s.upper()  # s is now "HELLO, WORLD! HOW ARE YOU?"
print(s)
d = s.lower()
print(d)
print(s)
# Out:
# HELLO, WORLD! HOW ARE YOU?
# hello, world! how are you?
# HELLO, WORLD! HOW ARE YOU?

# %%
s = 'Hello, World!'

# Concatenate two strings (will print Hello, World! Nice meeting you!)
print(s + ' Nice meeting you!')

# Replace a character
s[0] = 'h'  # This will produce an error as strings are immutable

# Concatenate two strings
s += 'How are you?'  # s is now "Hello, World! How are you?"

# Make a string uppercase
s = s.upper()  # s is now "HELLO, WORLD! HOW ARE YOU?"

# Make a string lowercase
s = s.lower()  # s is now "hello, world! how are you?"

# Split a string into a list of words
words = s.split()  # words is ['hello,', 'world!', 'how', 'are', 'you?']

# %%
s.split()
# Out:
# ['HELLO,', 'WORLD!', 'HOW', 'ARE', 'YOU?']

# %%
print(s)
s.split('O')
# Out:
# HELLO, WORLD! HOW ARE YOU?
# ['HELL', ', W', 'RLD! H', 'W ARE Y', 'U?']

# %%
print(s)

s.replace('O', '0')
# Out:
# HELLO, WORLD! HOW ARE YOU?
# 'HELL0, W0RLD! H0W ARE Y0U?'

# %%
name = 'Anna'
print('Hello, {}!'.format(name))  # Will print `Hello, Anna!`
# Out:
# Hello, Anna!

# %%
name = 'Anna'
age = 25
print('{0} is {1} years old.'.format(name, age))  # Anna is 25 years old.
print('{1} is {0} years old.'.format(age, name))  # Anna is 25 years old.
# Out:
# Anna is 25 years old.
# Anna is 25 years old.

# %%
name = 'Anna'
age = 25
print('{name} is {age} years old. {name} is very smart!'.format(name=name, age=age))
# Will print `Anna is 25 years old. Anna is very smart!`
# Out:
# Anna is 25 years old. Anna is very smart!

# %%
name = 'Anna'
print('Hello, %s!' % name)  # Will print `Hello, Anna!`
# Out:
# Hello, Anna!

# %%
name = 'Anna'
age = 25.56778
print('%s is %d years old.' % (name, age))  # Anna is 25 years old.
# Out:
# Anna is 25 years old.

# %%
name = 'Anna'
print(f'Hello, {name}!')  # Will print `Hello, Anna!`
# Out:
# Hello, Anna!

# %%
name = 'Anna'
age = 24
print(f'{name} is {age + 1} years old.')  # Anna is 25 years old.
# Out:
# Anna is 25 years old.

# %%
price = 9.99
print(f'The price is ${price}')          # `The price is $9.99`

pi = 3.14159
print(f'Pi is approximately {pi:.4f}')   # `Pi is approximately 3.14`

x = 55
print(f'We can pad with zeros {x:04d}')  # `We can pad with zeros 0055`
print(f'Or pad with spaces {x:8d}')      # `Or pad with spaces       55`
print(f'Pad before with spaces {x:>8d}') # `Pad before with spaces       55`
print(f'Pad after with spaces {x:<8d}')  # `Pad after with spaces 55      `
print(f'Pad center with spaces {x:^8d}') # `Pad center with spaces    55
# Out:
# The price is $9.99
# Pi is approximately 3.1416
# We can pad with zeros 0055
# Or pad with spaces       55
# Pad before with spaces       55
# Pad after with spaces 55
# Pad center with spaces    55

# %%
n = 808017424794512875886459904961710757005754368000000000
print(f'The number is: {n:_d}')  # The number is: 808_017_424_794_512_875_886_459_904_961_710_757_005_754_368_000_000_000
print(f'The number is: {n:,d}')  # The number is: 808,017,424,794,512,875,886,459,904,961,710,757,005,754,368,000,000,000
# Out:
# The number is: 808_017_424_794_512_875_886_459_904_961_710_757_005_754_368_000_000_000
# The number is: 808,017,424,794,512,875,886,459,904,961,710,757,005,754,368,000,000,000

# %% [markdown]
# Get a number betwen 1 - 100
#
# if the number is less than 10 <= then print the x^e
# if the number is betweenb 10 and 90 then print the log 2  of the x
# if the number is between >= 90 and 100 then print the square root of the number
#
#
# Return all the nubers rounded by 3 digits
# all the other cases shall print(invalid number)

# %%
print(round(10**2.71828, 3))
# Out:
# 522.733

# %%
nmb = int(input('Give me a number'))
import math

if nmb >100 or nmb < 1:
    print('invalid number')
elif 1<= nmb <= 10:
    print(round(nmb**2.71828, 3))
elif 10 < nmb < 90:
    print(round(math.log2(nmb), 3))
else:   
    print(round(sqrt(nmb)))
# Out:
# 5.492
