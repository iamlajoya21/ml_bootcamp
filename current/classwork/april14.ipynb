# %% [markdown]
# Problem 1: The "Manual" Principal Component (Numpy)Objective: Prove you understand the underlying math by manually finding the first Principal Component without using sklearn.decomposition.The Data:Pythonimport numpy as np
#
# The Task:Center the data: Subtract the mean of each feature.Covariance Matrix: Calculate the $2 \times 2$ covariance matrix using np.cov.Eigen-Decomposition: Use np.linalg.eig to find the eigenvalues and eigenvectors.Identify $PC_1$: Which eigenvector corresponds to the largest eigenvalue? Explain what this vector represents in terms of "maximum variance."

# %%
import numpy as  np
X = np.array([[2, 3], [3, 4], [4, 5], [5, 6], [10, 11]])

# %% [markdown]
# Problem 2: Compression & Information Loss (Sklearn)
# Objective: Use the classic Iris dataset to observe how dimensionality reduction affects data representation.
#
# The Task:
#
# Load the Iris dataset (4 features).
#
# Apply PCA to reduce the dataset from 4 dimensions down to 2.
#
# The Scree Test: Print the explained_variance_ratio_.
#
# Analysis Question: What percentage of the total variance is "lost" by discarding the 3rd and 4th components? If you were a biologist, would you trust this 2D projection to represent the original data accurately?

# %% [markdown]
# Problem 3: The Scaling Sabotage (Practical ML)Objective: Observe how different units of measurement can "trick" PCA into giving the wrong answer.The Data:Imagine a dataset with two features for a car:Feature 1: Top speed in miles per hour (range 0–200).Feature 2: Engine displacement in cubic centimeters (range 1000–6000).The Task:Generate a synthetic dataset where Top Speed and Displacement are highly correlated.Run PCA on the raw data (without scaling). Note the direction of $PC_1$.Run PCA again, but this time use StandardScaler first.Comparison: How did the components change? Why does PCA "prefer" the feature with the larger numerical range if you don't scale?
