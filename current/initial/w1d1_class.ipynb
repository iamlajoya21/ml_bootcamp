# %%
1+2
# Out:
# 3

# %%
hello world
# Out:
#   Cell In[2], line 1
#     hello world
#           ^
# SyntaxError: invalid syntax

# %%
print("Hello, World!")
# Out:
# Hello, World!

# %%
print('Hello world")
# Out:
#   Cell In[3], line 1
#     print('Hello world")
#           ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
x = 2 
print(x)
# Out:
# 2

# %%
print('1', '2', '3', 'abc')
# Out:
# 1 2 3 abc

# %%
print("1*2  = ", 1*2)
print("3/5=", 3/5)
print(10**3)
# Out:
# 1*2  =  2
# 3/5= 0.6
# 1000

# %%
x = 2
print(x)
print(type(x))
x = 'Babken'
print(x)
print(type(x))
# Out:
# 2
# <class 'int'>
# Babken
# <class 'str'>

# %%
print('Hello', 'World!', sep='|')
print(42, 'is a great', 'number', sep='-')
# Out:
# Hello|World!
# 42-is a great-number

# %%
print('hello', 42, sep = '\n')
# Out:
# hello
# 42

# %%
input('Tell me a number')
# Out:
# '42'

# %%
print(10**2)
print(5**3)
# Out:
# 100
# 125
# 1.6666666666666667

# %%
print('Division')
print(10/6)
print('Whole Division')
print(10//6)

print('Remainder')
print(10%6)


print('New examples')
print(13%3)
print(23//3)
# Out:
# Division
# 1.6666666666666667
# Whole Division
# 1
# Remainder
# 4
# New examples
# 1
# 7

# %%
num = input('Enter an integer: ')  # Get input from the user
num = int(num)                     # Convert the input to an integer
print(num)
# Out:
# 21

# %%
x = '21'
print(x)
print(type(x))
x = int(x)
print(x)
print(type(x))
# Out:
# 21
# <class 'str'>
# 21
# <class 'int'>

# %%
x = '10b'
print(x)
print(type(x))
x = int(x)
print(x)
print(type(x))
# Out:
# 10b
# <class 'str'>
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[35], line 4
#       2 print(x)
#       3 print(type(x))
# ----> 4 x = int(x)
#       5 print(x)
#       6 print(type(x))
#
# ValueError: invalid literal for int() with base 10: '10b'

# %%
is_evening = True

# %%
is_morning = False
print(is_morning)
# Out:
# False

# %%
print(bool('True'))

print(bool(False))

print(bool(' '))

print(bool(''))
# Out:
# True
# False
# True
# False

# %%
bool(int('01'))
# Out:
# True

# %%
int('01')
# Out:
# 1

# %%
x = True
y = False 
z = True
print(x+y)
print(x+y+z)
print(int(bool(x+z)))
# Out:
# 1
# 2
# 1

# %%
print(x+z)
print(int(bool(x+z)))
# Out:
# 2
# 1

# %%
int(True)
# Out:
# 1

# %%
print( 1 and 1)
print( 0 and 0)
print( 1 and 0)
print( 1 and True)
print(12 and 10)



print(True or False)
print(False or True)
# Out:
# 1
# 0
# 0
# True
# 10
# True
# True
# False

# %%
a = 1

# %%
x = 2
if x > 5:
    print('x is greater than 5')
    print(x, 'is greater than 5')
else:
    print('x is not bigger than 5')
# Out:
# x is not bigger than 5

# %%
var = 1

# %% [markdown]
# Some Classwork examples

# %%
var = int(input("Enter a number: "))

if var >= 10:
    print(var * var)
else:
    print(var)
# Out:
# 100

# %%
x=4
if x >= 10:
    print(x**2)
else:
    print(x)
# Out:
# 4

# %%
var = int(input("Give a num: "))

if var >= 10:
    print(var**2)
else:
    print(var)
# Out:
# 3136

# %%
x = input("inpun an integer: ")

x= int(x)
try:
    if int(x) > 10:
        print(x **2)
    else:
        print(x)
except Exception as e:
    print(f"An error: {e}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[109], line 3
#       1 x = input("inpun an integer: ")
# ----> 3 x= int(x)
#       4 try:
#       5     if int(x) > 10:
#
# ValueError: invalid literal for int() with base 10: 'babken'

# %%
var = input()
if var>10:
    print(var**2)
else:
    print(var)

# %%
a= int(input('input a'))
if a > 10:
    print(a*a)
else: print(a)
# Out:
# 10

# %%
var = input("Enter a value: ")
if var >= 10:
    print(var)
else:
    print(var * var)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[112], line 2
#       1 var = input("Enter a value: ")
# ----> 2 if var >= 10:
#       3     print(var)
#       4 else:
#
# TypeError: '>=' not supported between instances of 'str' and 'int'

# %% [markdown]
# <h2> If Else & elif </h2>

# %%
x = 20

if  x> 10:
    print(x)

    if x>100:
       print('X is bigger than 100')

    else:
        print('X is bigger than 10 but it is not bigger than 100')

else:
    print('X is not bigger than 10')
# Out:
# 20
# X is bigger than 10 but it is not bigger than 100

# %%
a = 30
b = 30 


if a>b:
    print('A')
elif a==b:
    print('A=B')
else:
    print('B')
# Out:
# A=B

# %%
a = 100
b = 100 


if a>b and a > 100:
    print('A')
elif a==b and b < 100:
    print('A=B')
elif a<b:
    print('B')
else:
    print('Smth is wrong')
# Out:
# Smth is wrong
