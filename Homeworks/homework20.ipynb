# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("stefanoleone992/fifa-22-complete-player-dataset")

print("Path to dataset files:", path)

# %% [markdown]
# The Task: The "Total Footballer" Scouting Challenge
#
#
# Objective
#
# Your goal is to assist a professional football scouting department.
# They are overwhelmed by the 70+ attributes available for each of the 18,000+ players in the FIFA 22 dataset.
# They need a simplified 2D "Scouting Map" that categorizes players not by their position, but by their technical and physical profiles.
#
# Requirements
#
# Data Cleaning & Filtering:
#
# Load the FIFA 22 dataset.
# Remove Goalkeepers (their stats like 'GKDiving' are outliers that skew field-player PCA).
# Select at least 15 technical and physical features (e.g., pace, shooting, passing, agility, aggression).
# Handle missing values and apply Standardization.
#
#
# Analysis:
#
# Perform PCA on the full feature set.Generate a Scree Plot.
# Identify the minimum number of components required to retain 80% of the original variance.
#
# The Archetype Map:
#
# Reduce the data to 2 components ($PC_1$ and $PC_2$).
# Analyze the Feature Loadings to give $PC_1$ and $PC_2$ descriptive names (e.g., "The Playmaker Factor").
# Create a scatter plot of all players in the PCA space, colored by their overall rating or player_positions.
