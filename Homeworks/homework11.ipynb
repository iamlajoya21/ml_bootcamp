# %% [markdown]
# ## ✈️ Homework: Global Aviation Data Challenge
# Problem 1: The Brazilian Heliport Audit / Բրազիլական ուղղաթիռային հրապարակների աուդիտ
# English: Your company is expanding its drone delivery service to South America.
#
# Load the dataset and extract all facilities located in Brazil (iso_country is "BR") that are classified as heliports.
#
# Show only the name and the municipality where these heliports are located.
#
# How many heliports does Brazil have in this dataset?
#
# Հայերեն: Ձեր ընկերությունն ընդլայնում է անօդաչու թռչող սարքերի միջոցով առաքման ծառայությունը Հարավային Ամերիկայում:
#
# Բեռնեք տվյալների բազան և առանձնացրեք Բրազիլիայում (iso_country-ն «BR» է) գտնվող բոլոր այն օբյեկտները, որոնք դասակարգված են որպես ուղղաթիռային հրապարակներ (heliports):
#
# Ցուցադրեք միայն այդ հրապարակների name-ը (անունը) և municipality-ն (համայնքը):
#
# Ըստ այս տվյալների բազայի՝ քանի՞ ուղղաթիռային հրապարակ կա Բրազիլիայում:

# %% [markdown]
# ## Problem 2: The South American Slice / Հարավամերիկյան հատվածը
# English: You are reviewing the first entries of the global database for South American connectivity.
#
# Isolate the first 500 rows of the original dataset.
#
# From this subset, find all small airports located in the continent of South America (continent is "SA").
#
# Display the municipality and the coordinates for these specific airports.
#
# Հայերեն: Դուք վերանայում եք համաշխարհային տվյալների բազայի առաջին գրառումները՝ Հարավային Ամերիկայի կապն ուսումնասիրելու համար:
#
# Առանձնացրեք բնօրինակ տվյալների բազայի առաջին 500 տողերը:
#
# Այս ենթաբազմությունից գտեք բոլոր փոքր օդանավակայանները (small airports), որոնք գտնվում են Հարավային Ամերիկա մայրցամաքում (continent-ը «SA» է):
#
# Ցուցադրեք այդ օդանավակայանների municipality-ն և coordinates-ը (կոորդինատները):

# %% [markdown]
# ## Problem 3: Alpine Aviation Maintenance / Ալպիական ավիացիոն սպասարկում
# English: Maintenance teams need to check high-altitude sensors in Switzerland.
#
# Find all airports in Switzerland (iso_country is "CH") that are situated at an elevation higher than 4,000 feet.
#
# Data Correction: The elevation sensors for the first 3 airports in this Swiss list are known to be faulty. Change their elevation_ft value to 0 to flag them for manual inspection.
#
# Display the updated information for these 3 specific airports.
#
# Հայերեն: Սպասարկման թիմերը պետք է ստուգեն Շվեյցարիայի բարձրլեռնային սենսորները:
#
# Գտեք Շվեյցարիայի (iso_country-ն «CH» է) բոլոր այն օդանավակայանները, որոնք գտնվում են 4000 ֆուտից ավելի բարձրության վրա:
#
# Տվյալների ուղղում. Հայտնի է, որ այս շվեյցարական ցուցակի առաջին 3 օդանավակայանների բարձրության սենսորները անսարք են: Փոխեք դրանց elevation_ft արժեքը 0-ի՝ դրանք ձեռքով ստուգման համար նշելու նպատակով:
#
# Ցուցադրեք այս 3 կոնկրետ օդանավակայանների թարմացված տեղեկատվությունը:

# %% [markdown]
# ## Problem 4: Missing Regional Identifiers / Բացակայող տարածաշրջանային նույնականացուցիչները
# English: Some medium-sized airports in Great Britain are missing crucial GPS data.
#
# Filter the database for airports in the Great Britain region (iso_country is "GB") that are classified as medium_airport.
#
# From this filtered list, identify which airports are missing their gps_code (where the data is empty).
#
# Display the name and iso_region for these airports.
#
# Հայերեն: Մեծ Բրիտանիայի որոշ միջին չափի օդանավակայաններ չունեն կարևոր GPS տվյալներ:
#
# Զտեք տվյալների բազան Մեծ Բրիտանիայի (iso_country-ն «GB» է) այն օդանավակայանների համար, որոնք դասակարգված են որպես միջին օդանավակայան (medium_airport):
#
# Այս զտված ցանկից պարզեք, թե որ օդանավակայաններն ունեն բացակայող gps_code (որտեղ տվյալները դատարկ են):
#
# Ցուցադրեք այդ օդանավակայանների name-ը և iso_region-ը:

# %% [markdown]
# ## Problem 5: The Major Hub Search / Խոշոր հանգույցների որոնում
# English: You are creating a map of the world's most famous airports.
#
# Set the ident column as the index of your DataFrame.
#
# Using the index, retrieve the complete row of data for the following three airports: "EGLL" (London Heathrow), "RJTT" (Tokyo Haneda), and "LFPG" (Paris Charles de Gaulle).
#
# Find all airports in Japan (iso_country is "JP") that are currently closed.
#
# Հայերեն: Դուք ստեղծում եք աշխարհի ամենահայտնի օդանավակայանների քարտեզը:
#
# Սահմանեք ident սյունը որպես ձեր DataFrame-ի ինդեքս:
#
# Օգտագործելով ինդեքսը, ստացեք հետևյալ երեք օդանավակայանների տվյալների ամբողջական տողերը՝ «EGLL» (Լոնդոնի Հիթրոու), «RJTT» (Տոկիոյի Հանեդա) և «LFPG» (Փարիզի Շառլ դը Գոլ):
#
# Գտեք Ճապոնիայի (iso_country-ն «JP» է) բոլոր այն օդանավակայանները, որոնք ներկայումս փակ են (closed):

# %%
# --- Solution 5: Hub Indexing & Japan Audit ---
# Set index to 'ident'
df_indexed = df.set_index('ident')
# Label-based retrieval
major_hubs = df_indexed.loc[['EGLL', 'RJTT', 'LFPG']]
# Find closed airports in Japan
closed_japan = df[(df['iso_country'] == 'JP') & (df['type'] == 'closed')]

# %%
df
# Out:
#          ident           type                       name  elevation_ft  \
# 0          00A       heliport          Total RF Heliport          11.0
# 1         00AA  small_airport       Aero B Ranch Airport        3435.0
# 2         00AK  small_airport               Lowell Field         450.0
# 3         00AL  small_airport               Epps Airpark         820.0
# 4         00AN  small_airport       Katmai Lodge Airport          80.0
# ...        ...            ...                        ...           ...
# 82803  ZZ-0001       heliport            Sealand Helipad          40.0
# 82804  ZZ-0002  small_airport  Glorioso Islands Airstrip          11.0
# 82805  ZZ-0003  small_airport      Fainting Goat Airport         690.0
# 82806  ZZ-0004       heliport          Penzance Heliport           NaN
# 82807     ZZZZ  small_airport     Satsuma Iōjima Airport         338.0
#
#       continent iso_country iso_region        municipality icao_code  \
# ...

# %%
df_indexed.index
# Out:
# Index(['00A', '00AA', '00AK', '00AL', '00AN', '00AS', '00AZ', '00CA', '00CL',
#        '00CN',
#        ...
#        'ZYTX', 'ZYXC', 'ZYYJ', 'ZYYK', 'ZYYY', 'ZZ-0001', 'ZZ-0002', 'ZZ-0003',
#        'ZZ-0004', 'ZZZZ'],
#       dtype='str', name='ident', length=82808)

# %%
import pandas as pd
import ssl

# Fix SSL Certification issues``
ssl._create_default_https_context = ssl._create_unverified_context

# Load the Global Dataset
url = "https://raw.githubusercontent.com/datasets/airport-codes/refs/heads/main/data/airport-codes.csv"
df = pd.read_csv(url)

# %%
#option 1 

df_f = df[df['iso_country']== 'BR']
df_f[df_f['type'] == 'heliport']
# Out:
#          ident      type                                             name  \
# 12809  BR-0017  heliport  Guarulhos - Sao Paulo Airport Marriott Heliport
# 12810  BR-0018  heliport                            Fasano Hotel Heliport
# 12811  BR-0019  heliport                       Fazenda Boa Vista Heliport
# 12812  BR-0020  heliport                 Semp Toshiba Jordanésia Heliport
# 12813  BR-0021  heliport                            Praia Grande Heliport
# ...        ...       ...                                              ...
# 62668     SWYB  heliport                         Chácara Messias Heliport
# 62683     SWYZ  heliport                      Residência Oficial Heliport
# 62691     SWZI  heliport                                Multitoc Heliport
# 62692     SWZK  heliport                      CON-CN-Cidade Nova Heliport
# 62701     SWZZ  heliport                                   Graer Heliport
#
#        elevation_ft continent iso_country iso_region    municipality  \
# ...

# %%
# --- Solution 1: Brazil Heliports ---
# Filter by country and type
br_heliports = df[(df['iso_country'] == 'BR') & (df['type'] == 'heliport')]
# Select specific columns
ans_1 = br_heliports[['name', 'municipality']]
count_br = len(br_heliports)
print(f"Total Heliports in Brazil: {count_br}")
# Out:
# Total Heliports in Brazil: 1870

# %%
# --- Solution 2: SA Slice ---
# Positional indexing for first 500
first_500 = df[:50000]
# Filter within the slice
sa_small = first_500[(first_500['continent'] == 'SA') & (first_500['type'] == 'small_airport')]
ans_2 = sa_small[['municipality', 'coordinates']]

# %%
# --- Solution 3: Swiss Elevation Correction ---
# Find high-altitude Swiss airports
swiss_high = df[(df['iso_country'] == 'CH') & (df['elevation_ft'] > 4000)]
# Use positional indexing to update first 3 values
# Assuming elevation_ft is column index 3
# Note: We use .index[0:3] to get the specific labels of the filtered result
faulty_indices = swiss_high.index[:3]
df.loc[faulty_indices, 'elevation_ft'] = 0
ans_3 = df.loc[faulty_indices]

# %%
ans_3
# Out:
#          ident           type                       name  elevation_ft  \
# 18344  CH-0002  small_airport    Croix de Coeur Altiport           0.0
# 18348  CH-0006       heliport  Helipad Station Corvatsch           0.0
# 18349  CH-0007         closed          Ulrichen Air Base           0.0
#
#       continent iso_country iso_region municipality icao_code iata_code  \
# 18344        EU          CH      CH-VS       Riddes       NaN       NaN
# 18348        EU          CH      CH-GR      Sanedan       NaN       NaN
# 18349        EU          CH      CH-VS     Obergoms       NaN       NaN
#
#       gps_code local_code          coordinates
# 18344      NaN        NaN  46.123348, 7.234131
# 18348      NaN        NaN  46.417572, 9.820629
# 18349      NaN        NaN   46.50193, 8.299415

# %%
# Out:
# continent
# AS    12166
# EU    11965
# SA    11369
# OC     4138
# AF     4086
# AN       44
# Name: count, dtype: int64

# %%
df.continent.isna().sum()
# Out:
# 39040

# %%
import numpy as np
np.nan == None
# Out:
# False

# %%
bool('NaN')
# Out:
# True

# %%
bool(None)
# Out:
# False

# %%
gb_medium[gb_medium['gps_code'] ]

# %%
# --- Solution 4: Missing GPS Data in GB ---
# Filter GB Medium airports
gb_medium = df[(df['iso_country'] == 'GB') & (df['type'] == 'medium_airport') & (df['gps_code'].isna()) ]
# Find missing values (NaN)
missing_gps = gb_medium[gb_medium['gps_code'].isna()]
ans_4 = missing_gps[['name', 'iso_region']]

# %%
import pandas as pd
import ssl

# Fix SSL Certification issues``
ssl._create_default_https_context = ssl._create_unverified_context

# Load the Global Dataset
url = "https://raw.githubusercontent.com/datasets/airport-codes/refs/heads/main/data/airport-codes.csv"
df = pd.read_csv(url)

# --- Solution 1: Brazil Heliports ---
# Filter by country and type
br_heliports = df[(df['iso_country'] == 'BR') & (df['type'] == 'heliport')]
# Select specific columns
ans_1 = br_heliports[['name', 'municipality']]
count_br = len(br_heliports)
print(f"Total Heliports in Brazil: {count_br}")

# --- Solution 2: SA Slice ---
# Positional indexing for first 500
first_500 = df.iloc[:500]
# Filter within the slice
sa_small = first_500[(first_500['continent'] == 'SA') & (first_500['type'] == 'small_airport')]
ans_2 = sa_small[['municipality', 'coordinates']]

# --- Solution 3: Swiss Elevation Correction ---
# Find high-altitude Swiss airports
swiss_high = df[(df['iso_country'] == 'CH') & (df['elevation_ft'] > 4000)]
# Use positional indexing to update first 3 values
# Assuming elevation_ft is column index 3
# Note: We use .index[0:3] to get the specific labels of the filtered result
faulty_indices = swiss_high.index[:3]
df.loc[faulty_indices, 'elevation_ft'] = 0
ans_3 = df.loc[faulty_indices]

# --- Solution 4: Missing GPS Data in GB ---
# Filter GB Medium airports
gb_medium = df[(df['iso_country'] == 'GB') & (df['type'] == 'medium_airport')]
# Find missing values (NaN)
missing_gps = gb_medium[gb_medium['gps_code'].isna()]
ans_4 = missing_gps[['name', 'iso_region']]

# --- Solution 5: Hub Indexing & Japan Audit ---
# Set index to 'ident'
df_indexed = df.set_index('ident')
# Label-based retrieval
major_hubs = df_indexed.loc[['EGLL', 'RJTT', 'LFPG']]
# Find closed airports in Japan
closed_japan = df[(df['iso_country'] == 'JP') & (df['type'] == 'closed')]
# Out:
# Total Heliports in Brazil: 1870
